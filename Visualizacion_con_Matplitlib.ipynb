# %% [markdown]
# <a href="https://colab.research.google.com/github/aboltCD/aboltCD/blob/main/Visualizacion_con_Matplitlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Visualizaciones Utiles con Matplotlib

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('/content/diabetes_train.csv')
df.head()
# Out:
#    Patient ID  Pregnancies  Glucose  ...  DiabetesPedigreeFunction  Age  Diabetes
# 0           1            6      148  ...                     0.627   50       Yes
# 1           2            1       85  ...                     0.351   31        No
# 2           3            8      183  ...                     0.672   32       Yes
# 3           4            1       89  ...                     0.167   21        No
# 4           5            0      137  ...                     2.288   33       Yes
#
# [5 rows x 10 columns]

# %% [markdown]
# ahora hacemos un heatmap de correlación entre variables con **seaborn**:

# %%
plt.figure(figsize=(12,10), dpi= 80)
sns.heatmap(df.corr(), xticklabels=df.corr().columns, yticklabels=df.corr().columns, cmap='RdYlGn', center=0, annot=True)

# Decorations
plt.title('Correlograma de Diabetes', fontsize=22)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %% [markdown]
# Análisis visual de correlación por combinación de variables, separadas por clase (color), CON regresión:

# %%
plt.figure(figsize=(10,8), dpi= 80)
sns.pairplot(df, kind="reg", hue="Diabetes")
plt.show()

# %%
plt.figure(figsize=(10,8), dpi= 80)
sns.pairplot(df, kind="scatter", hue="Diabetes", plot_kws=dict(s=80, edgecolor="white", linewidth=2.5))
plt.show()
